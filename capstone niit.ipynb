# %%
import pandas as pd
import numpy as np
import os
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from scipy import stats
import warnings
warnings.filterwarnings("ignore")

# %%
df=pd.read_csv("DS1_C8_V3_ND_Sprint2_Data Analysis Using Python_Dataset.csv")

# %%
df
# Out:
#          budget                                             genres  \
# 0     237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1     300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2     245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3     250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4     260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# ...         ...                                                ...
# 4798     220000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4799       9000  [{"id": 35, "name": "Comedy"}, {"id": 10749, "...
# 4800          0  [{"id": 35, "name": "Comedy"}, {"id": 18, "nam...
# 4801          0                                                 []
# 4802          0                [{"id": 99, "name": "Documentary"}]
#
#                                                homepage      id  \
# 0                           http://www.avatarmovie.com/   19995
# ...

# %%
df.columns
# Out:
# Index(['budget', 'genres', 'homepage', 'id', 'keywords', 'original_language',
#        'original_title', 'overview', 'popularity', 'production_companies',
#        'production_countries', 'release_date', 'revenue', 'runtime',
#        'spoken_languages', 'status', 'tagline', 'title', 'vote_average',
#        'vote_count'],
#       dtype='object')

# %%
df.shape
# Out:
# (4803, 20)

# %%
df.describe()
# Out:
#              budget             id   popularity       revenue      runtime  \
# count  4.803000e+03    4803.000000  4803.000000  4.803000e+03  4801.000000
# mean   2.904504e+07   57165.484281    21.492301  8.226064e+07   106.875859
# std    4.072239e+07   88694.614033    31.816650  1.628571e+08    22.611935
# min    0.000000e+00       5.000000     0.000000  0.000000e+00     0.000000
# 25%    7.900000e+05    9014.500000     4.668070  0.000000e+00    94.000000
# 50%    1.500000e+07   14629.000000    12.921594  1.917000e+07   103.000000
# 75%    4.000000e+07   58610.500000    28.313505  9.291719e+07   118.000000
# max    3.800000e+08  459488.000000   875.581305  2.787965e+09   338.000000
#
#        vote_average    vote_count
# count   4803.000000   4803.000000
# mean       6.092172    690.217989
# std        1.194612   1234.585891
# min        0.000000      0.000000
# 25%        5.600000     54.000000
# 50%        6.200000    235.000000
# 75%        6.800000    737.000000
# ...

# %%
df.iloc[:,1].head(50)
# Out:
# 0     [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1     [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2     [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3     [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4     [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 5     [{"id": 14, "name": "Fantasy"}, {"id": 28, "na...
# 6     [{"id": 16, "name": "Animation"}, {"id": 10751...
# 7     [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 8     [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 9     [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 10    [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 11    [{"id": 12, "name": "Adventure"}, {"id": 28, "...
# 12    [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 13    [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 14    [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 15    [{"id": 12, "name": "Adventure"}, {"id": 10751...
# 16    [{"id": 878, "name": "Science Fiction"}, {"id"...
# ...

# %%
#In Python, the "ast" (Abstract Syntax Trees) library is a built-in module that provides a way to work with and manipulate Python source code at an abstract syntax tree level. It allows you to parse Python code and analyze its structure, extract information, and even modify the code programmatically.

# %%
# convert a column of genre representations in a DataFrame into a more usable format by extracting and storing only the genre names.

import ast
# Define a function to extract genre names from a string representation of genres
def convert(text):
    genres = []  # Initialize an empty list to store genre names
    for i in ast.literal_eval(text):  # Convert the string into a list of dictionaries using safe evaluation
        genres.append(i['name'])  # Retrieve the name of each genre dictionary and add it to the list
    return genres  # Return the list of genre names

# Apply the 'convert' function to the 'genres' column of the 'movies' DataFrame
df['genres'] =  df['genres'].apply(convert)

# %%
df[["genres","original_title"]].head(50)
# Out:
#                                                genres  \
# 0       [Action, Adventure, Fantasy, Science Fiction]
# 1                        [Adventure, Fantasy, Action]
# 2                          [Action, Adventure, Crime]
# 3                    [Action, Crime, Drama, Thriller]
# 4                [Action, Adventure, Science Fiction]
# 5                        [Fantasy, Action, Adventure]
# 6                                 [Animation, Family]
# 7                [Action, Adventure, Science Fiction]
# 8                        [Adventure, Fantasy, Family]
# 9                        [Action, Adventure, Fantasy]
# 10      [Adventure, Fantasy, Action, Science Fiction]
# 11               [Adventure, Action, Thriller, Crime]
# 12                       [Adventure, Fantasy, Action]
# 13                       [Action, Adventure, Western]
# 14      [Action, Adventure, Fantasy, Science Fiction]
# 15                       [Adventure, Family, Fantasy]
# ...

# %%
# Apply the 'convert' function to the 'keywords' column of the 'movies' DataFrame
df['keywords'] =  df['keywords'].apply(convert)

# %%
df.head(50)
# Out:
#        budget                                             genres  \
# 0   237000000      [Action, Adventure, Fantasy, Science Fiction]
# 1   300000000                       [Adventure, Fantasy, Action]
# 2   245000000                         [Action, Adventure, Crime]
# 3   250000000                   [Action, Crime, Drama, Thriller]
# 4   260000000               [Action, Adventure, Science Fiction]
# 5   258000000                       [Fantasy, Action, Adventure]
# 6   260000000                                [Animation, Family]
# 7   280000000               [Action, Adventure, Science Fiction]
# 8   250000000                       [Adventure, Fantasy, Family]
# 9   250000000                       [Action, Adventure, Fantasy]
# 10  270000000      [Adventure, Fantasy, Action, Science Fiction]
# 11  200000000               [Adventure, Action, Thriller, Crime]
# 12  200000000                       [Adventure, Fantasy, Action]
# ...

# %%
# convert a column of genre representations in a DataFrame into a more usable format by extracting and storing only the genre names.

import ast
# Define a function to extract genre names from a string representation of genres
def convert(text):
    genres = []  # Initialize an empty list to store genre names
    for i in ast.literal_eval(text):  # Convert the string into a list of dictionaries using safe evaluation
        genres.append(i['name'])  # Retrieve the name of each genre dictionary and add it to the list
    return genres  # Return the list of genre names

# Apply the 'convert' function to the 'genres' column of the 'movies' DataFrame
df['production_companies'] =  df['production_companies'].apply(convert)

# %%
df['production_companies']
# Out:
# 0       [Ingenious Film Partners, Twentieth Century Fo...
# 1       [Walt Disney Pictures, Jerry Bruckheimer Films...
# 2                        [Columbia Pictures, Danjaq, B24]
# 3       [Legendary Pictures, Warner Bros., DC Entertai...
# 4                                  [Walt Disney Pictures]
#                               ...
# 4798                                  [Columbia Pictures]
# 4799                                                   []
# 4800    [Front Street Pictures, Muse Entertainment Ent...
# 4801                                                   []
# 4802         [rusty bear entertainment, lucky crow films]
# Name: production_companies, Length: 4803, dtype: object

# %%
production_counts = df['production_companies'].value_counts()

# %%
df['production_companies'] = df['production_companies'].apply(lambda x: ', '.join(x) if isinstance(x, list) else x)

# %%
production_counts = df['production_companies'].value_counts()

# %%
production_counts
# Out:
#                                                                                                                                                                                                                                                                                                                             351
# Paramount Pictures                                                                                                                                                                                                                                                                                                           58
# Universal Pictures                                                                                                                                                                                                                                                                                                           45
# ...

# %%
# Assuming you have already calculated the production_counts as shown before
top_25_production_companies = production_counts.head(25)
print(top_25_production_companies)
# Out:
#                                                        351
# Paramount Pictures                                      58
# Universal Pictures                                      45
# New Line Cinema                                         38
# Columbia Pictures                                       37
# Metro-Goldwyn-Mayer (MGM)                               32
# Twentieth Century Fox Film Corporation                  31
# Warner Bros.                                            27
# Walt Disney Pictures                                    27
# Touchstone Pictures                                     26
# Dimension Films                                         17
# Columbia Pictures Corporation                           16
# Miramax Films                                           16
# DreamWorks Animation                                    12
# United Artists                                          12
# Walt Disney Pictures, Pixar Animation Studios           11
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Assuming you have already calculated the production_counts as shown before
top_25_production_companies = production_counts.head(25)

# Set plot style (optional)
sns.set(style="whitegrid")

# Plot the bar chart
plt.figure(figsize=(12, 6))
sns.barplot(x=top_25_production_companies.index, y=top_25_production_companies.values)
plt.xticks(rotation=90)
plt.xlabel('Production Company')
plt.ylabel('Number of Movies Produced')
plt.title('Top 25 Production Companies by Number of Movies Produced')
plt.show()

# %%
df.isnull().sum()
# Out:
# budget                     0
# genres                     0
# homepage                3091
# id                         0
# keywords                   0
# original_language          0
# original_title             0
# overview                   3
# popularity                 0
# production_companies       0
# production_countries       0
# release_date               1
# revenue                    0
# runtime                    2
# spoken_languages           0
# status                     0
# tagline                  844
# title                      0
# vote_average               0
# vote_count                 0
# dtype: int64

# %%
# Replace null values with "Not Mentioned"
df_filled = df.fillna("Not Mentioned")
print(df_filled)
# Out:
#          budget                                         genres  \
# 0     237000000  [Action, Adventure, Fantasy, Science Fiction]
# 1     300000000                   [Adventure, Fantasy, Action]
# 2     245000000                     [Action, Adventure, Crime]
# 3     250000000               [Action, Crime, Drama, Thriller]
# 4     260000000           [Action, Adventure, Science Fiction]
# ...         ...                                            ...
# 4798     220000                      [Action, Crime, Thriller]
# 4799       9000                              [Comedy, Romance]
# 4800          0             [Comedy, Drama, Romance, TV Movie]
# 4801          0                                             []
# 4802          0                                  [Documentary]
#
#                                                homepage      id  \
# 0                           http://www.avatarmovie.com/   19995
# 1          http://disney.go.com/disneypictures/pirates/     285
# ...

# %%
df_filled.isnull().sum()
# Out:
# budget                  0
# genres                  0
# homepage                0
# id                      0
# keywords                0
# original_language       0
# original_title          0
# overview                0
# popularity              0
# production_companies    0
# production_countries    0
# release_date            0
# revenue                 0
# runtime                 0
# spoken_languages        0
# status                  0
# tagline                 0
# title                   0
# vote_average            0
# vote_count              0
# dtype: int64

# %%
df_filled
# Out:
#          budget                                         genres  \
# 0     237000000  [Action, Adventure, Fantasy, Science Fiction]
# 1     300000000                   [Adventure, Fantasy, Action]
# 2     245000000                     [Action, Adventure, Crime]
# 3     250000000               [Action, Crime, Drama, Thriller]
# 4     260000000           [Action, Adventure, Science Fiction]
# ...         ...                                            ...
# 4798     220000                      [Action, Crime, Thriller]
# 4799       9000                              [Comedy, Romance]
# 4800          0             [Comedy, Drama, Romance, TV Movie]
# 4801          0                                             []
# 4802          0                                  [Documentary]
#
#                                                homepage      id  \
# 0                           http://www.avatarmovie.com/   19995
# 1          http://disney.go.com/disneypictures/pirates/     285
# ...

# %%
movies_higher_budget = df_filled[(df_filled["budget"]>220000)]

# %%
movies_higher_budget
# Out:
#          budget                                         genres  \
# 0     237000000  [Action, Adventure, Fantasy, Science Fiction]
# 1     300000000                   [Adventure, Fantasy, Action]
# 2     245000000                     [Action, Adventure, Crime]
# 3     250000000               [Action, Crime, Drama, Thriller]
# 4     260000000           [Action, Adventure, Science Fiction]
# ...         ...                                            ...
# 4680     450000                      [Crime, Horror, Thriller]
# 4682   13000000                                       [Horror]
# 4720    8500000                                        [Drama]
# 4758    4000000                    [Thriller, Science Fiction]
# 4770     500000                                [Drama, Comedy]
#
#                                               homepage      id  \
# 0                          http://www.avatarmovie.com/   19995
# 1         http://disney.go.com/disneypictures/pirates/     285
# ...

# %%
movies_higher_revenue = df_filled[(df_filled["revenue"]>961000000)]

# %%
movies_higher_revenue
# Out:
#         budget                                          genres  \
# 0    237000000   [Action, Adventure, Fantasy, Science Fiction]
# 3    250000000                [Action, Crime, Drama, Thriller]
# 7    280000000            [Action, Adventure, Science Fiction]
# 12   200000000                    [Adventure, Fantasy, Action]
# 16   220000000            [Science Fiction, Action, Adventure]
# 17   380000000                    [Adventure, Action, Fantasy]
# 25   200000000                      [Drama, Romance, Thriller]
# 26   250000000            [Adventure, Action, Science Fiction]
# 28   150000000  [Action, Adventure, Science Fiction, Thriller]
# 29   200000000                   [Action, Adventure, Thriller]
# 31   200000000            [Action, Adventure, Science Fiction]
# 32   200000000                    [Family, Fantasy, Adventure]
# 36   210000000            [Science Fiction, Action, Adventure]
# 42   200000000                     [Animation, Family, Comedy]
# ...

# %%
df_filled = df_filled.drop(df_filled[df_filled['budget'] == 0].index)

# %%
df_filled
# Out:
#          budget                                         genres  \
# 0     237000000  [Action, Adventure, Fantasy, Science Fiction]
# 1     300000000                   [Adventure, Fantasy, Action]
# 2     245000000                     [Action, Adventure, Crime]
# 3     250000000               [Action, Crime, Drama, Thriller]
# 4     260000000           [Action, Adventure, Science Fiction]
# ...         ...                                            ...
# 4791         13                                       [Horror]
# 4792      20000             [Crime, Horror, Mystery, Thriller]
# 4796       7000             [Science Fiction, Drama, Thriller]
# 4798     220000                      [Action, Crime, Thriller]
# 4799       9000                              [Comedy, Romance]
#
#                                           homepage      id  \
# 0                      http://www.avatarmovie.com/   19995
# 1     http://disney.go.com/disneypictures/pirates/     285
# ...

# %%
df_filled = df_filled.drop(df_filled[df_filled['revenue'] == 0].index)

# %%
df_filled
# Out:
#          budget                                         genres  \
# 0     237000000  [Action, Adventure, Fantasy, Science Fiction]
# 1     300000000                   [Adventure, Fantasy, Action]
# 2     245000000                     [Action, Adventure, Crime]
# 3     250000000               [Action, Crime, Drama, Thriller]
# 4     260000000           [Action, Adventure, Science Fiction]
# ...         ...                                            ...
# 4773      27000                                       [Comedy]
# 4788      12000                        [Horror, Comedy, Crime]
# 4792      20000             [Crime, Horror, Mystery, Thriller]
# 4796       7000             [Science Fiction, Drama, Thriller]
# 4798     220000                      [Action, Crime, Thriller]
#
#                                           homepage      id  \
# 0                      http://www.avatarmovie.com/   19995
# 1     http://disney.go.com/disneypictures/pirates/     285
# ...

# %%
top_highest_revenue_ten = df_filled.sort_values('revenue' , ascending = False)

# %%
print("top 10 highest revenue movies: \n\n",top_highest_revenue_ten.loc[: , 'original_title'].head(10))
# Out:
# top 10 highest revenue movies:
#
#  0                          Avatar
# 25                        Titanic
# 16                   The Avengers
# 28                 Jurassic World
# 44                      Furious 7
# 7         Avengers: Age of Ultron
# 124                        Frozen
# 31                     Iron Man 3
# 546                       Minions
# 26     Captain America: Civil War
# Name: original_title, dtype: object

# %%
least_budget_ten = df_filled.sort_values('budget' , ascending = True)

# %%
least_budget_ten.head(10)
# Out:
#       budget                                             genres  \
# 4238       1                                    [Drama, Comedy]
# 3611       4                              [Drama, Romance, War]
# 3372       7  [Thriller, Action, Horror, Science Fiction, Cr...
# 3419       7                  [Comedy, Drama, Foreign, Romance]
# 4608       8                        [Fantasy, Horror, Thriller]
# 3131      10                           [Drama, Romance, Comedy]
# 3137      10                                 [Horror, Thriller]
# 2933      11                                    [Drama, Action]
# 1912      25                                            [Drama]
# 1771      28                  [Thriller, Action, Comedy, Crime]
#
#                         homepage      id  \
# 4238               Not Mentioned    3082
# 3611               Not Mentioned   22649
# 3372               Not Mentioned   13006
# 3419               Not Mentioned   38415
# 4608               Not Mentioned   11980
# ...

# %%
least_budget_ten.loc[: , 'original_title'].head(10)
# Out:
# 4238          Modern Times
# 3611    A Farewell to Arms
# 3372          Split Second
# 3419          Bran Nue Dae
# 4608          The Prophecy
# 3131           Hross í oss
# 3137             Nurse 3-D
# 2933              F.I.S.T.
# 1912        Angela's Ashes
# 1771        The 51st State
# Name: original_title, dtype: object

# %%
correlation = top_highest_revenue_ten['revenue'].corr(top_highest_revenue_ten['budget'])
print(f"Correlation between Budget and Popularity: {correlation}")
# Out:
# Correlation between Budget and Popularity: 0.7053993306781382

# %%
plt.figure(figsize=(8, 6))
plt.scatter(top_highest_revenue_ten['budget'], top_highest_revenue_ten['revenue'], alpha=0.7)
plt.xlabel('Movie Budgets')
plt.ylabel('Popularity')
plt.title('Relationship between Movie Budgets and Popularity')
plt.grid(True)
plt.show()

# %%
heat = df_filled.corr()
plt.figure(figsize = [16,8])
plt.title("Correlation between numerical features", size = 25, pad = 20, color = '#8cabb6')
sns.heatmap(heat, cmap = sns.diverging_palette(20, 220, n = 200), annot = False)
plt.show()

# %%
top_500_revenue=df_filled.sort_values("revenue", ascending = False).head(500)

# %%
top_500_revenue
# Out:
#          budget                                          genres  \
# 0     237000000   [Action, Adventure, Fantasy, Science Fiction]
# 25    200000000                      [Drama, Romance, Thriller]
# 16    220000000            [Science Fiction, Action, Adventure]
# 28    150000000  [Action, Adventure, Science Fiction, Thriller]
# 44    190000000                                        [Action]
# ...         ...                                             ...
# 397    85000000                               [Comedy, Romance]
# 1744   30000000                        [Comedy, Romance, Drama]
# 698    70000000    [Adventure, Animation, Drama, Family, Music]
# 717    60000000                        [Crime, Drama, Thriller]
# 714    65000000                        [Drama, Crime, Thriller]
#
#                                homepage      id  \
# 0           http://www.avatarmovie.com/   19995
# 25          http://www.titanicmovie.com     597
# 16    http://marvel.com/avengers_movie/   24428
# ...

# %%
sns.boxplot(top_500_revenue['budget'])
# Out:
# <AxesSubplot:xlabel='budget'>

# %%
# Calculate the IQR for each numerical column
q1 = top_500_revenue['budget'].quantile(0.25)
q3 = top_500_revenue['budget'].quantile(0.75)
iqr = q3 - q1

# Define upper and lower bounds for outliers
lower_bound = q1 - 1.5 * iqr
upper_bound = q3 + 1.5 * iqr

# Identify outliers
outliers = ((top_500_revenue['budget'] < lower_bound) | (top_500_revenue['budget'] > upper_bound))


# Replace outliers with the nearest non-outlier value
top_500_revenue['budget'][outliers] = np.nan
top_500_revenue['budget'].fillna(method='ffill', inplace=True)

# %%
sns.boxplot(top_500_revenue['budget'])
# Out:
# <AxesSubplot:xlabel='budget'>

# %%
sns.boxplot(top_500_revenue['revenue'])
# Out:
# <AxesSubplot:xlabel='revenue'>

# %%
# Calculate the IQR for each numerical column
q1 = top_500_revenue['revenue'].quantile(0.25)
q3 = top_500_revenue['revenue'].quantile(0.75)
iqr = q3 - q1

# Define upper and lower bounds for outliers
lower_bound = q1 - 1.5 * iqr
upper_bound = q3 + 1.5 * iqr

# Identify outliers
outliers = ((top_500_revenue['revenue'] < lower_bound) | (top_500_revenue['revenue'] > upper_bound))


# Replace outliers with the nearest non-outlier value
top_500_revenue['revenue'][outliers] = np.nan
top_500_revenue['revenue'].fillna(method='ffill', inplace=True)

# %%
sns.boxplot(top_500_revenue['revenue'])
# Out:
# <AxesSubplot:xlabel='revenue'>

# %%
# Calculate the interquartile range (IQR)
Q1 = df_filled['revenue'].quantile(0.25)
Q3 = df_filled['revenue'].quantile(0.75)
IQR = Q3 - Q1

# Define upper and lower bounds to identify outliers
upper_bound = Q3 + 1.5 * IQR
lower_bound = Q1 - 1.5 * IQR

# Cap the outliers
df_filled['revenue'] = df_filled['revenue'].clip(lower=lower_bound, upper=upper_bound)

# %%
sns.boxplot(df_filled['revenue'])
# Out:
# <AxesSubplot:xlabel='revenue'>

# %% [markdown]
# By using the .clip() method, we set any budget value below the lower_bound to the lower_bound value and any value above the upper_bound to the upper_bound value, effectively capping the outliers.
#
# Remember that the choice of outlier treatment depends on the specific characteristics of your dataset and the goals of your analysis. It's essential to carefully consider the impact of outlier handling on your results and interpretations. Additionally, consulting with domain experts or statisticians can provide valuable insights into the appropriate approach for your particular analysis.

# %%
sns.boxplot(top_500_revenue['runtime'])
# Out:
# <AxesSubplot:xlabel='runtime'>

# %%
 #Calculate the interquartile range (IQR)
Q1 = df_filled['runtime'].quantile(0.25)
Q3 = df_filled['runtime'].quantile(0.75)
IQR = Q3 - Q1

# Define upper and lower bounds to identify outliers
upper_bound = Q3 + 1.5 * IQR
lower_bound = Q1 - 1.5 * IQR

# Cap the outliers
df_filled['runtime'] = df_filled['runtime'].clip(lower=lower_bound, upper=upper_bound)

# %%
sns.boxplot(df_filled['runtime'])
# Out:
# <AxesSubplot:xlabel='runtime'>

# %%
333
